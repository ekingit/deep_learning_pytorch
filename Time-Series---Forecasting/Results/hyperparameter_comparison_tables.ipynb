# %%
import pandas as pd

# %%
df = pd.read_csv('periodic/Hyperparameter_Performance_Analysis.csv',index_col=None)
df = df.drop(columns='Unnamed: 0')
df.sort_values('test_loss')[:10]
# Out:
#             model  hidden_size  num_layers    run_time  device  best_epoch  \
# 19  LSTM_periodic           50           1   71.345890  T4_GPU         304
# 12   RNN_periodic          200           1   93.085885  T4_GPU        3487
# 2    RNN_periodic           10           3  113.528239  T4_GPU        9975
# 20  LSTM_periodic          100           1  195.413320  T4_GPU        9922
# 0    RNN_periodic           10           1   64.119393  T4_GPU        9999
# 17  LSTM_periodic           10           1   80.464625  T4_GPU        6937
# 6    RNN_periodic           50           1   50.418628  T4_GPU        6179
# 7    RNN_periodic           50           2   81.937725  T4_GPU        7125
# 21  LSTM_periodic          300           1  822.268215  T4_GPU        4138
# 5    RNN_periodic           20           3   98.574208  T4_GPU        4143
#
#     num_epoch  test_loss  val_loss  train_loss
# 19      10000   0.215365  0.226382    0.297025
# 12      10000   0.217873  0.220988    0.271002
# ...

# %%
df = pd.read_csv('local/Hyperparameter_Performance_Analysis.csv',index_col=None)
df = df.drop(columns='Unnamed: 0')
df.sort_values('test_loss')[:10]
# Out:
#          model  seq_len  hidden_size  num_layers    run_time  device  \
# 25  local_LSTM       14           20           3  589.825269  T4_GPU
# 4   local_LSTM       14           50           2  276.291463  T4_GPU
# 0   local_LSTM       14           50           1  217.172130  T4_GPU
# 7   local_LSTM       30           50           1  239.605630  T4_GPU
# 11  local_LSTM       30           50           2  277.303764  T4_GPU
# 2   local_LSTM       14          200           1  266.106761  T4_GPU
# 5   local_LSTM       14          100           2  305.382567  T4_GPU
# 12  local_LSTM       30          100           2  413.595561  T4_GPU
# 3   local_LSTM       14          300           1  335.484305  T4_GPU
# 23  local_LSTM       14           20           1  223.921456  T4_GPU
#
#     best_epoch  num_epoch  test_loss  val_loss  train_loss
# 25         748       1500   0.231894  0.244068    0.274047
# 4          405        800   0.232691  0.244123    0.276388
# ...
